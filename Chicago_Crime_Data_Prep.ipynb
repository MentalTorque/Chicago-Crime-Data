# 7730207                                     $500 AND UNDER
# 7730208                            DOMESTIC BATTERY SIMPLE
#
#                 Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                          RESIDENCE   False     False  1433     14.00   NaN
# 1                          RESIDENCE   False     False   523      5.00 34.00
# 2                             STREET   False     False   911      9.00   NaN
# 3                             STREET    True     False   313      3.00   NaN
# 4                          RESIDENCE   False     False  2521     25.00   NaN
# ...                              ...     ...       ...   ...       ...   ...
# 7730204                    APARTMENT    True      True   231      2.00  3.00
# 7730205                    RESIDENCE   False      True  1633     16.00 30.00
# 7730206                        ALLEY    True     False  1532     15.00 37.00
# 7730207  RESIDENCE - PORCH / HALLWAY   False     False   212      2.00  3.00
# 7730208                   DRUG STORE    True      True   222      2.00  4.00
#
#          Latitude  Longitude
# 0           41.91     -87.67
# 1           41.67     -87.64
# 2           41.81     -87.69
# 3           41.78     -87.61
# 4           41.93     -87.74
# ...           ...        ...
# 7730204     41.80     -87.62
# 7730205     41.94     -87.76
# 7730206     41.89     -87.75
# 7730207     41.83     -87.62
# 7730208     41.81     -87.59
#
# [15460418 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    971738
# 2002    973598
# 2003    951958
# 2004    938836
# 2005    907534
# 2006    896346
# 2007    874162
# 2008    854320
# 2009    785632
# 2010    740980
# 2011    703916
# 2012    672510
# 2013    614906
# 2014    551444
# 2015    529464
# 2016    539540
# 2017    538074
# 2018    537468
# 2019    522394
# 2020    424038
# 2021    416770
# 2022    473434
# 2023     41356
# Name: Date, dtype: int64

# %%
# File is too large to to push to GitHub...  ## set save location 
# OUTPUT_FOLDER = 'C:/Users/staichn/OneDrive - Coherent, Inc/Documents/GitHub/Chicago Crime Data/Data/'

# os.makedirs(OUTPUT_FOLDER, exist_ok=True)
# print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")

# fname_temp = f"{OUTPUT_FOLDER}Starting_Data.csv"#.gz
    
# df.to_csv(fname_temp,index=False)

# print(f"- Succesfully saved {fname_temp}")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticks
import matplotlib.dates as mdates
plt.rcParams['figure.figsize'] = (12,3)

# %%
def summarize_df(df_):
    df = df_.copy()
    report = pd.DataFrame({
                        'dtype':df.dtypes,
                        '# null': df.isna().sum(),
                        'null (%)': df.isna().sum()/len(df)*100,
                        'nunique':df.nunique(),
                        "min":df.min(),
                        'max':df.max()
             })
    report.index.name='Column'
    return report.reset_index()
summarize_df(df)
# Out:
# C:\Users\staichn\AppData\Local\Temp\ipykernel_33192\861501889.py:8: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   "min":df.min(),
# C:\Users\staichn\AppData\Local\Temp\ipykernel_33192\861501889.py:9: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   'max':df.max()
#                   Column    dtype   # null  null (%)  nunique  \
# 0                 Arrest     bool        0      0.00        2
# 1                   Beat    int64        0      0.00      304
# 2                   Date   object        0      0.00  3181543
# 3            Description   object        0      0.00      543
# 4               District  float64       94      0.00       24
# 5               Domestic     bool        0      0.00        2
# 6                     ID    int64        0      0.00  7730209
# 7               Latitude  float64   169030      1.09   887828
# 8   Location Description   object    20046      0.13      215
# 9              Longitude  float64   169030      1.09   887241
# 10          Primary Type   object        0      0.00       36
# 11                  Ward  float64  1229694      7.95       50
#
#                        min                     max
# 0                    False                    True
# 1                      111                    2535
# 2   01/01/2001 01:00:00 AM  12/31/2022 12:59:00 PM
# 3           $300 AND UNDER         WIREROOM/SPORTS
# 4                     1.00                   31.00
# 5                    False                    True
# 6                      634                12976545
# 7                    36.62                   42.02
# 8                      NaN                     NaN
# 9                   -91.69                  -87.52
# 10                   ARSON       WEAPONS VIOLATION
# 11                    1.00                   50.00

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0         2001-01-01 13:00:00
# 1         2001-01-01 13:00:00
# 2         2001-01-01 13:00:00
# 3         2001-01-01 13:00:00
# 4         2001-01-01 13:00:00
#                   ...
# 7730204   2023-02-01 00:50:00
# 7730205   2023-02-01 12:53:00
# 7730206   2023-02-01 12:53:00
# 7730207   2023-02-01 12:54:00
# 7730208   2023-02-01 12:57:00
# Name: Date, Length: 15460418, dtype: datetime64[ns]

# %%
chrono_df = df.set_index('Date')
chrono_df.info()
chrono_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15460418 entries, 2001-01-01 13:00:00 to 2023-02-01 12:57:00
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Primary Type          object
#  2   Description           object
#  3   Location Description  object
#  4   Arrest                bool
#  5   Domestic              bool
#  6   Beat                  int64
#  7   District              float64
#  8   Ward                  float64
#  9   Latitude              float64
#  10  Longitude             float64
# dtypes: bool(2), float64(4), int64(2), object(3)
# memory usage: 1.2+ GB
#                            ID            Primary Type  \
# Date
# 2001-01-01 13:00:00   1311732  PUBLIC PEACE VIOLATION
# 2001-01-01 13:00:00   3769790                   THEFT
# 2001-01-01 13:00:00   1317380         CRIMINAL DAMAGE
# 2001-01-01 13:00:00   1324743                GAMBLING
# 2001-01-01 13:00:00   1427622           OTHER OFFENSE
# ...                       ...                     ...
# 2023-02-01 00:50:00  12969478                 BATTERY
# 2023-02-01 12:53:00  12970000                 BATTERY
# 2023-02-01 12:53:00  12969899               NARCOTICS
# 2023-02-01 12:54:00  12971229                   THEFT
# 2023-02-01 12:57:00  12970024                 BATTERY
#
#                                                            Description  \
# Date
# 2001-01-01 13:00:00                                       ARSON THREAT
# 2001-01-01 13:00:00                            AGG: FINANCIAL ID THEFT
# 2001-01-01 13:00:00                                         TO VEHICLE
# 2001-01-01 13:00:00                                ILLEGAL ILL LOTTERY
# 2001-01-01 13:00:00                            HARASSMENT BY TELEPHONE
# ...                                                                ...
# 2023-02-01 00:50:00                            DOMESTIC BATTERY SIMPLE
# 2023-02-01 12:53:00  AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING ...
# 2023-02-01 12:53:00     MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS
# 2023-02-01 12:54:00                                     $500 AND UNDER
# 2023-02-01 12:57:00                            DOMESTIC BATTERY SIMPLE
#
#                             Location Description  Arrest  Domestic  Beat  \
# Date
# 2001-01-01 13:00:00                    RESIDENCE   False     False  1433
# 2001-01-01 13:00:00                    RESIDENCE   False     False   523
# 2001-01-01 13:00:00                       STREET   False     False   911
# 2001-01-01 13:00:00                       STREET    True     False   313
# 2001-01-01 13:00:00                    RESIDENCE   False     False  2521
# ...                                          ...     ...       ...   ...
# 2023-02-01 00:50:00                    APARTMENT    True      True   231
# 2023-02-01 12:53:00                    RESIDENCE   False      True  1633
# 2023-02-01 12:53:00                        ALLEY    True     False  1532
# 2023-02-01 12:54:00  RESIDENCE - PORCH / HALLWAY   False     False   212
# 2023-02-01 12:57:00                   DRUG STORE    True      True   222
#
#                      District  Ward  Latitude  Longitude
# Date
# 2001-01-01 13:00:00     14.00   NaN     41.91     -87.67
# 2001-01-01 13:00:00      5.00 34.00     41.67     -87.64
# 2001-01-01 13:00:00      9.00   NaN     41.81     -87.69
# 2001-01-01 13:00:00      3.00   NaN     41.78     -87.61
# 2001-01-01 13:00:00     25.00   NaN     41.93     -87.74
# ...                       ...   ...       ...        ...
# 2023-02-01 00:50:00      2.00  3.00     41.80     -87.62
# 2023-02-01 12:53:00     16.00 30.00     41.94     -87.76
# 2023-02-01 12:53:00     15.00 37.00     41.89     -87.75
# 2023-02-01 12:54:00      2.00  3.00     41.83     -87.62
# 2023-02-01 12:57:00      2.00  4.00     41.81     -87.59
#
# [15460418 rows x 11 columns]

# %%
chrono_df.index
# Out:
# DatetimeIndex(['2001-01-01 13:00:00', '2001-01-01 13:00:00',
#                '2001-01-01 13:00:00', '2001-01-01 13:00:00',
#                '2001-01-01 13:00:00', '2001-01-01 13:00:00',
#                '2001-01-01 01:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 13:00:00', '2001-01-01 01:00:00',
#                ...
#                '2023-02-01 12:37:00', '2023-02-01 12:40:00',
#                '2023-02-01 12:41:00', '2023-02-01 00:43:00',
#                '2023-02-01 12:45:00', '2023-02-01 00:50:00',
#                '2023-02-01 12:53:00', '2023-02-01 12:53:00',
#                '2023-02-01 12:54:00', '2023-02-01 12:57:00'],
#               dtype='datetime64[ns]', name='Date', length=15460418, freq=None)

# %%
#Quick Function for EDA analysis (proper EDA should still be conducted)

def summarize_df(df_):
    df = df_.copy()
    report = pd.DataFrame({
        'dtype':df.dtypes,
        '# null': df.isna().sum(),
        'null %': df.isna().sum()/len(df)*100,
        'nunique': df.nunique(),
        'min':df.min(),
        'max':df.max()        
    })
    report.index.name='Column'
    return report.reset_index()
summarize_df(chrono_df)
# Out:
# C:\Users\staichn\AppData\Local\Temp\ipykernel_33192\3464280240.py:10: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   'min':df.min(),
# C:\Users\staichn\AppData\Local\Temp\ipykernel_33192\3464280240.py:11: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   'max':df.max()
#                   Column    dtype   # null  null %  nunique             min  \
# 0                 Arrest     bool        0    0.00        2           False
# 1                   Beat    int64        0    0.00      304             111
# 2            Description   object        0    0.00      543  $300 AND UNDER
# 3               District  float64       94    0.00       24            1.00
# 4               Domestic     bool        0    0.00        2           False
# 5                     ID    int64        0    0.00  7730209             634
# 6               Latitude  float64   169030    1.09   887828           36.62
# 7   Location Description   object    20046    0.13      215             NaN
# 8              Longitude  float64   169030    1.09   887241          -91.69
# 9           Primary Type   object        0    0.00       36           ARSON
# 10                  Ward  float64  1229694    7.95       50            1.00
#
#                   max
# 0                True
# 1                2535
# 2     WIREROOM/SPORTS
# 3               31.00
# 4                True
# 5            12976545
# 6               42.02
# 7                 NaN
# 8              -87.52
# 9   WEAPONS VIOLATION
# 10              50.00

# %% [markdown]
# # 1) Comparing Police Districts:
#
# * Which district has the most crimes? Which has the least?

# %%
district_df = chrono_df.groupby('District').nunique()
district_df
# Out:
#               ID  Primary Type  Description  Location Description  Arrest  \
# District
# 1.00      311703            33          422                   155       2
# 2.00      365727            35          438                   161       2
# 3.00      392062            34          444                   160       2
# 4.00      438849            35          447                   153       2
# 5.00      342882            35          431                   155       2
# 6.00      451823            33          444                   152       2
# 7.00      448029            32          435                   154       2
# 8.00      519631            33          446                   159       2
# 9.00      378014            34          440                   147       2
# 10.00     333071            33          439                   154       2
# 11.00     496623            35          466                   156       2
# 12.00     382361            33          454                   153       2
# 14.00     299348            33          427                   142       2
# 15.00     331997            34          440                   149       2
# 16.00     258372            33          422                   148       2
# 17.00     223043            32          408                   140       2
# 18.00     346549            34          419                   152       2
# 19.00     346710            33          429                   148       2
# 20.00     136505            32          382                   141       2
# 21.00          4             3            4                     4       2
# 22.00     253344            32          414                   142       2
# 24.00     233285            32          410                   143       2
# 25.00     439998            33          451                   142       2
# 31.00        232            19           63                    39       2
#
#           Domestic  Beat  Ward  Latitude  Longitude
# District
# 1.00             2    37    14     17045      17045
# 2.00             2    46    16     35147      35142
# 3.00             2    36    10     31402      31423
# 4.00             2    27    10     51260      51212
# 5.00             2    26    14     41038      41041
# 6.00             2    39    13     42112      42128
# 7.00             2    36    13     40245      40246
# 8.00             2    37    18     76881      76884
# 9.00             2    47    17     52741      52759
# 10.00            2    33    19     36025      36028
# 11.00            2    37    11     39859      39870
# 12.00            2    64    25     49736      49732
# 14.00            2    32    16     40210      40216
# 15.00            2    18     8     27386      27386
# 16.00            2    35    16     53988      53992
# 17.00            2    27    17     38588      38594
# 18.00            2    32    15     26144      26152
# 19.00            2    46    19     44748      44752
# 20.00            2    24    12     19458      19459
# 21.00            2     1     1         1          1
# 22.00            2    29    14     42835      42850
# 24.00            2    19     9     28997      29008
# 25.00            2    38    20     58581      58601
# 31.00            2    50    31        95         95

# %%
dist_hist = district_df.sort_values('ID', ascending = False)
dist_hist
# Out:
#               ID  Primary Type  Description  Location Description  Arrest  \
# District
# 8.00      519631            33          446                   159       2
# 11.00     496623            35          466                   156       2
# 6.00      451823            33          444                   152       2
# 7.00      448029            32          435                   154       2
# 25.00     439998            33          451                   142       2
# 4.00      438849            35          447                   153       2
# 3.00      392062            34          444                   160       2
# 12.00     382361            33          454                   153       2
# 9.00      378014            34          440                   147       2
# 2.00      365727            35          438                   161       2
# 19.00     346710            33          429                   148       2
# 18.00     346549            34          419                   152       2
# 5.00      342882            35          431                   155       2
# 10.00     333071            33          439                   154       2
# 15.00     331997            34          440                   149       2
# 1.00      311703            33          422                   155       2
# 14.00     299348            33          427                   142       2
# 16.00     258372            33          422                   148       2
# 22.00     253344            32          414                   142       2
# 24.00     233285            32          410                   143       2
# 17.00     223043            32          408                   140       2
# 20.00     136505            32          382                   141       2
# 31.00        232            19           63                    39       2
# 21.00          4             3            4                     4       2
#
#           Domestic  Beat  Ward  Latitude  Longitude
# District
# 8.00             2    37    18     76881      76884
# 11.00            2    37    11     39859      39870
# 6.00             2    39    13     42112      42128
# 7.00             2    36    13     40245      40246
# 25.00            2    38    20     58581      58601
# 4.00             2    27    10     51260      51212
# 3.00             2    36    10     31402      31423
# 12.00            2    64    25     49736      49732
# 9.00             2    47    17     52741      52759
# 2.00             2    46    16     35147      35142
# 19.00            2    46    19     44748      44752
# 18.00            2    32    15     26144      26152
# 5.00             2    26    14     41038      41041
# 10.00            2    33    19     36025      36028
# 15.00            2    18     8     27386      27386
# 1.00             2    37    14     17045      17045
# 14.00            2    32    16     40210      40216
# 16.00            2    35    16     53988      53992
# 22.00            2    29    14     42835      42850
# 24.00            2    19     9     28997      29008
# 17.00            2    27    17     38588      38594
# 20.00            2    24    12     19458      19459
# 31.00            2    50    31        95         95
# 21.00            2     1     1         1          1

# %%
ax = dist_hist['ID'].plot.bar(title = 'Crimes per District')

# %% [markdown]
# There is an interesting distribution of crime across Chicago when looking at the total dataset from 2001 to 2023.
#
# The District with the highest number of crimes in that period is the 8th District with 519,631 crimes.
#
# The district with the least number of crimes is the 21st District with 4.
#
# This last data point seems suspect statistically, as does the low number of crimes reported in the 31st District (232 crimes since 2001).
#
# Considering the overall crime volumes throughout the city over the period, it would be unlikely for two districts to report such low crime levels.
#
# It seems that the district with the most reliable numbers relative to the rest of the city for the lowest crime volume is the 20th District with 136,505 crimes.

# %% [markdown]
# # 2) Crimes Across the Years:
#
# * Is the total number of crimes increasing or decreasing across the years?
#
# * Are there any individual crimes that are doing the opposite (e.g decreasing when overall crime is increasing or vice-versa)?

# %%
annual_df = chrono_df.resample('Y').count()
#annual_df.value_count('id')
annual_df
# Out:
#                 ID  Primary Type  Description  Location Description  Arrest  \
# Date
# 2001-12-31  971738        971738       971738                971728  971738
# 2002-12-31  973598        973598       973598                973588  973598
# 2003-12-31  951958        951958       951958                951950  951958
# 2004-12-31  938836        938836       938836                938806  938836
# 2005-12-31  907534        907534       907534                907498  907534
# 2006-12-31  896346        896346       896346                896310  896346
# 2007-12-31  874162        874162       874162                874116  874162
# 2008-12-31  854320        854320       854320                854238  854320
# 2009-12-31  785632        785632       785632                785528  785632
# 2010-12-31  740980        740980       740980                740836  740980
# 2011-12-31  703916        703916       703916                703310  703916
#                   2020-12-31                 16862   16862     16862  16862
#                   2021-12-31                 17956   17956     17956  17956
#                   2022-12-31                 17452   17452     17452  17452
#                   2023-12-31                  1512    1512      1512   1512
#
#                               District   Ward  Latitude  Longitude
# Primary Type      Date
# ARSON             2001-12-31      2022      8      2010       2010
#                   2002-12-31      2064   1446      1956       1956
#                   2003-12-31      1910   1910      1906       1906
#                   2004-12-31      1556   1556      1548       1548
#                   2005-12-31      1382   1382      1376       1376
# ...                                ...    ...       ...        ...
# WEAPONS VIOLATION 2019-12-31     12678  12676     12676      12676
#                   2020-12-31     16862  16862     16832      16832
#                   2021-12-31     17956  17956     17890      17890
#                   2022-12-31     17452  17450     17396      17396
#                   2023-12-31      1512   1512      1512       1512
#
# [750 rows x 11 columns]

# %%
crimes_df = plot_df.drop(columns='Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Latitude', 'Longitude')
crimes_unstacked = crimes.unstack(level=0)
crimes_unstacked.name = "Crimes over Time"
crimes_unstacked
# Out:
#   Cell In [71], line 1
#     crimes_df = plot_df.drop(columns='Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Latitude', 'Longitude');
#                                                                                                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
ax = indiv_crimes['Primary Type'].plot()

# %%
indiv_crimes.sort_values('Primary Type')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 indiv_crimes.sort_values('Primary Type')
#
# File ~\Anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\Anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:6909, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6905 elif len(by):
#    6906     # len(by) == 1
#    6908     by = by[0]
# -> 6909     k = self._get_label_or_level_values(by, axis=axis)
#    6911     # need to rewrap column in Series to apply key function
#    6912     if key is not None:
#    6913         # error: Incompatible types in assignment (expression has type
#    6914         # "Series", variable has type "ndarray")
#
# File ~\Anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:1838, in NDFrame._get_label_or_level_values(self, key, axis)
#    1835 other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1837 if self._is_label_reference(key, axis=axis):
# -> 1838     self._check_label_or_level_ambiguity(key, axis=axis)
#    1839     values = self.xs(key, axis=other_axes[0])._values
#    1840 elif self._is_level_reference(key, axis=axis):
#    1841     # error: Incompatible types in assignment (expression has type "Union[
#    1842     # ExtensionArray, ndarray[Any, Any]]", variable has type "ndarray[Any,
#    1843     # Any]")
#
# File ~\Anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:1797, in NDFrame._check_label_or_level_ambiguity(self, key, axis)
#    1789 label_article, label_type = (
#    1790     ("a", "column") if axis == 0 else ("an", "index")
#    1791 )
#    1793 msg = (
#    1794     f"'{key}' is both {level_article} {level_type} level and "
#    1795     f"{label_article} {label_type} label, which is ambiguous."
#    1796 )
# -> 1797 raise ValueError(msg)
#
# ValueError: 'Primary Type' is both an index level and a column label, which is ambiguous.
